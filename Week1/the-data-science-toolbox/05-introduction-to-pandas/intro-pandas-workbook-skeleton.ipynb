# %% [markdown]
# ## Part 1: Importing, examining, and updating values in a dataset

# %%
import pandas as pd

# %% [markdown]
# **Use the `.read_csv()` method to import the file `libraries.csv` from the `data` folder, assigning the result to `df`:**

# %%
cd /Users/senhintse/Desktop/Apprenticeship/Week1/the-data-science-toolbox/05-introduction-to-pandas/data/
# Out:
# /Users/senhintse/Desktop/Apprenticeship/Week1/the-data-science-toolbox/05-introduction-to-pandas/data

# %%
df = pd.read_csv("libraries.csv")
df
# Out:
#            Library service                 Library name In use 2010  \
# 0     Barking and Dagenham                      Barking         Yes
# 1     Barking and Dagenham                 Castle Green         Yes
# 2     Barking and Dagenham                     Dagenham          No
# 3     Barking and Dagenham                     Fanshawe         Yes
# 4     Barking and Dagenham                   Marks Gate         Yes
# ...                    ...                          ...         ...
# 3272                  York   Rowntree Park reading cafe          No
# 3273                  York                    Strensall         yes
# 3274                  York  Sycamore House reading cafe          no
# 3275                  York                    Tang Hall         yes
# 3276                  York                         York         yes
#
#      In use 2016 Type of library Type of closed library  Closed New building  \
# 0            Yes             LAL                    NaN     NaN          NaN
# 1             No             NaN                     XL  Mar-13          NaN
# 2            Yes             LAL                    NaN     NaN       Oct-10
# 3             No             NaN                    XLR  Sep-10          NaN
# 4            Yes             CRL                    NaN     NaN          NaN
# ...          ...             ...                    ...     ...          ...
# 3272         Yes              CL                    NaN     NaN         2013
# 3273         yes              CL                    NaN     NaN          NaN
# 3274         yes              CL                    NaN     NaN          NaN
# 3275         yes              CL                    NaN     NaN          NaN
# 3276         yes              CL                    NaN     NaN          NaN
#
#      Replace existing                                              Notes  \
# 0                 NaN                                                NaN
# 1                 NaN  Closed as a public library 31.3.2013. Secondar...
# 2                 Yes            Replaced Fanshawe and Rectory libraries
# 3                 NaN  Closed September 2010 replaced by Dagenham Lib...
# 4                 NaN  Volunteer led with local authority staff suppo...
# ...               ...                                                ...
# 3272               No                                                NaN
# 3273              NaN                                                NaN
# 3274              NaN                                                NaN
# 3275              NaN                                                NaN
# 3276              NaN  Closed for refurb June 2014 to January 2015 fo...
#
#       Weekly hours open  Weekly hours staffed
# 0                  72.0                  72.0
# 1                   NaN                   NaN
# 2                  56.0                  56.0
# 3                   NaN                   NaN
# 4                   9.0                   9.0
# ...                 ...                   ...
# 3272               45.5                  45.5
# 3273               19.0                  19.0
# 3274                NaN                   NaN
# 3275               41.0                  41.0
# 3276               65.0                  65.0
#
# [3277 rows x 12 columns]

# %% [markdown]
# **Check that the file has been imported as expected using the `.head()` method to look at the first `3` rows of `df`:**

# %%
df.head(3)
# Out:
#         Library service  Library name In use 2010 In use 2016 Type of library  \
# 0  Barking and Dagenham       Barking         Yes         Yes             LAL
# 1  Barking and Dagenham  Castle Green         Yes          No             NaN
# 2  Barking and Dagenham      Dagenham          No         Yes             LAL
#
#   Type of closed library  Closed New building Replace existing  \
# 0                    NaN     NaN          NaN              NaN
# 1                     XL  Mar-13          NaN              NaN
# 2                    NaN     NaN       Oct-10              Yes
#
#                                                Notes  Weekly hours open  \
# 0                                                NaN               72.0
# 1  Closed as a public library 31.3.2013. Secondar...                NaN
# 2            Replaced Fanshawe and Rectory libraries               56.0
#
#    Weekly hours staffed
# 0                  72.0
# 1                   NaN
# 2                  56.0

# %% [markdown]
# **Use the `.shape` attribute to find out the number of rows and columns in `df`, assigning the number of rows to `rows` and number of columns to `cols`:**

# %%
rows = df.shape[0]
cols = df.shape[1]

# %%
print(rows)
print(cols)
# Out:
# 3277
# 12

# %% [markdown]
# **Use the `.describe()` method on `df` to look at some statistics for the numerical data columns:**

# %%
df.describe()
# Out:
#        Weekly hours open  Weekly hours staffed
# count        2798.000000           2797.000000
# mean           35.734407             35.737529
# std            30.952803             30.957897
# min           -57.000000            -57.000000
# 25%            21.000000             21.000000
# 50%            33.500000             33.500000
# 75%            45.000000             45.000000
# max           674.340000            674.340000

# %% [markdown]
# Notice that the value for `min` in both columns is negative, which suggests an error in the data.
#
# **You're told that there is an error in the row with index `2233`; use `.loc[]` to have a look at this row:**

# %%
df.loc[[2233]]
# Out:
#      Library service    Library name In use 2010 In use 2016 Type of library  \
# 2233     Oxfordshire  Oxford Central         yes          no             LAL
#
#      Type of closed library Closed New building Replace existing  \
# 2233                    XLT   2016          NaN              NaN
#
#                                                   Notes  Weekly hours open  \
# 2233  Refurbished 2012.  Currently, temporarily clos...              -57.0
#
#       Weekly hours staffed
# 2233                 -57.0

# %% [markdown]
# **Using `.loc[]`, update the values for both `Weekly hours open` and `Weekly hours staffed` on this row to `57`:**

# %%
df.loc[[2233],'Weekly hours open'] = 57
df.loc[[2233],'Weekly hours staffed'] = 57
df.loc[[2233]]
# Out:
#      Library service    Library name In use 2010 In use 2016 Type of library  \
# 2233     Oxfordshire  Oxford Central         yes          no             LAL
#
#      Type of closed library Closed New building Replace existing  \
# 2233                    XLT   2016          NaN              NaN
#
#                                                   Notes  Weekly hours open  \
# 2233  Refurbished 2012.  Currently, temporarily clos...               57.0
#
#       Weekly hours staffed
# 2233                  57.0

# %% [markdown]
# - Run your code again for the previous question to check that both values on the row at index `2233` have been updated.
#
# The `min` value for these columns (which can be seen again using the `.describe()` method on the DataFrame, or the `.min()` method on a given column), should now be `0`:

# %%
df.loc[:, ['Weekly hours open','Weekly hours staffed']].min()
# Out:
# Weekly hours open       0.0
# Weekly hours staffed    0.0
# dtype: float64

# %%
df.loc[:, ['Weekly hours open','Weekly hours staffed']].describe()
# Out:
#        Weekly hours open  Weekly hours staffed
# count        2798.000000           2797.000000
# mean           35.775150             35.778287
# std            30.905686             30.910767
# min             0.000000              0.000000
# 25%            21.000000             21.000000
# 50%            33.500000             33.500000
# 75%            45.000000             45.000000
# max           674.340000            674.340000

# %% [markdown]
# ## Part 2: Filtering, sorting, and modifying DataFrames

# %% [markdown]
# **Use the `.set_index()` method to use the values from the `Library name` column as the index of `df`, using the parameter `inplace=True`:**

# %%
df.set_index('Library name',inplace=True)
df
# Out:
#                                   Library service In use 2010 In use 2016  \
# Library name
# Barking                      Barking and Dagenham         Yes         Yes
# Castle Green                 Barking and Dagenham         Yes          No
# Dagenham                     Barking and Dagenham          No         Yes
# Fanshawe                     Barking and Dagenham         Yes          No
# Marks Gate                   Barking and Dagenham         Yes         Yes
# ...                                           ...         ...         ...
# Rowntree Park reading cafe                   York          No         Yes
# Strensall                                    York         yes         yes
# Sycamore House reading cafe                  York          no         yes
# Tang Hall                                    York         yes         yes
# York                                         York         yes         yes
#
#                             Type of library Type of closed library  Closed  \
# Library name
# Barking                                 LAL                    NaN     NaN
# Castle Green                            NaN                     XL  Mar-13
# Dagenham                                LAL                    NaN     NaN
# Fanshawe                                NaN                    XLR  Sep-10
# Marks Gate                              CRL                    NaN     NaN
# ...                                     ...                    ...     ...
# Rowntree Park reading cafe               CL                    NaN     NaN
# Strensall                                CL                    NaN     NaN
# Sycamore House reading cafe              CL                    NaN     NaN
# Tang Hall                                CL                    NaN     NaN
# York                                     CL                    NaN     NaN
#
#                             New building Replace existing  \
# Library name
# Barking                              NaN              NaN
# Castle Green                         NaN              NaN
# Dagenham                          Oct-10              Yes
# Fanshawe                             NaN              NaN
# Marks Gate                           NaN              NaN
# ...                                  ...              ...
# Rowntree Park reading cafe          2013               No
# Strensall                            NaN              NaN
# Sycamore House reading cafe          NaN              NaN
# Tang Hall                            NaN              NaN
# York                                 NaN              NaN
#
#                                                                          Notes  \
# Library name
# Barking                                                                    NaN
# Castle Green                 Closed as a public library 31.3.2013. Secondar...
# Dagenham                               Replaced Fanshawe and Rectory libraries
# Fanshawe                     Closed September 2010 replaced by Dagenham Lib...
# Marks Gate                   Volunteer led with local authority staff suppo...
# ...                                                                        ...
# Rowntree Park reading cafe                                                 NaN
# Strensall                                                                  NaN
# Sycamore House reading cafe                                                NaN
# Tang Hall                                                                  NaN
# York                         Closed for refurb June 2014 to January 2015 fo...
#
#                              Weekly hours open  Weekly hours staffed
# Library name
# Barking                                   72.0                  72.0
# Castle Green                               NaN                   NaN
# Dagenham                                  56.0                  56.0
# Fanshawe                                   NaN                   NaN
# Marks Gate                                 9.0                   9.0
# ...                                        ...                   ...
# Rowntree Park reading cafe                45.5                  45.5
# Strensall                                 19.0                  19.0
# Sycamore House reading cafe                NaN                   NaN
# Tang Hall                                 41.0                  41.0
# York                                      65.0                  65.0
#
# [3277 rows x 11 columns]

# %% [markdown]
# **Use the `.drop()` method to remove the `Notes` column:**
# - remember to use `axis=1`
# - use `inplace=True`

# %%
df.drop('Notes',inplace = True, axis = 1)
df
# Out:
#                                   Library service In use 2010 In use 2016  \
# Library name
# Barking                      Barking and Dagenham         Yes         Yes
# Castle Green                 Barking and Dagenham         Yes          No
# Dagenham                     Barking and Dagenham          No         Yes
# Fanshawe                     Barking and Dagenham         Yes          No
# Marks Gate                   Barking and Dagenham         Yes         Yes
# ...                                           ...         ...         ...
# Rowntree Park reading cafe                   York          No         Yes
# Strensall                                    York         yes         yes
# Sycamore House reading cafe                  York          no         yes
# Tang Hall                                    York         yes         yes
# York                                         York         yes         yes
#
#                             Type of library Type of closed library  Closed  \
# Library name
# Barking                                 LAL                    NaN     NaN
# Castle Green                            NaN                     XL  Mar-13
# Dagenham                                LAL                    NaN     NaN
# Fanshawe                                NaN                    XLR  Sep-10
# Marks Gate                              CRL                    NaN     NaN
# ...                                     ...                    ...     ...
# Rowntree Park reading cafe               CL                    NaN     NaN
# Strensall                                CL                    NaN     NaN
# Sycamore House reading cafe              CL                    NaN     NaN
# Tang Hall                                CL                    NaN     NaN
# York                                     CL                    NaN     NaN
#
#                             New building Replace existing  Weekly hours open  \
# Library name
# Barking                              NaN              NaN               72.0
# Castle Green                         NaN              NaN                NaN
# Dagenham                          Oct-10              Yes               56.0
# Fanshawe                             NaN              NaN                NaN
# Marks Gate                           NaN              NaN                9.0
# ...                                  ...              ...                ...
# Rowntree Park reading cafe          2013               No               45.5
# Strensall                            NaN              NaN               19.0
# Sycamore House reading cafe          NaN              NaN                NaN
# Tang Hall                            NaN              NaN               41.0
# York                                 NaN              NaN               65.0
#
#                              Weekly hours staffed
# Library name
# Barking                                      72.0
# Castle Green                                  NaN
# Dagenham                                     56.0
# Fanshawe                                      NaN
# Marks Gate                                    9.0
# ...                                           ...
# Rowntree Park reading cafe                   45.5
# Strensall                                    19.0
# Sycamore House reading cafe                   NaN
# Tang Hall                                    41.0
# York                                         65.0
#
# [3277 rows x 10 columns]

# %% [markdown]
# **Create a function called `open_2016` which takes two parameters called `data` and `name`, where `data` is a DataFrame (such as `df`) and `name` is a string (such as the values in `Library name`, which we have set as the index), and returns the value in the `In use 2016` column for the row whose index is equal to `name`:**
#
# - use the `.loc[]` method

# %%
df.reset_index()
# Out:
#                      Library name       Library service In use 2010  \
# 0                         Barking  Barking and Dagenham         Yes
# 1                    Castle Green  Barking and Dagenham         Yes
# 2                        Dagenham  Barking and Dagenham          No
# 3                        Fanshawe  Barking and Dagenham         Yes
# 4                      Marks Gate  Barking and Dagenham         Yes
# ...                           ...                   ...         ...
# 3272   Rowntree Park reading cafe                  York          No
# 3273                    Strensall                  York         yes
# 3274  Sycamore House reading cafe                  York          no
# 3275                    Tang Hall                  York         yes
# 3276                         York                  York         yes
#
#      In use 2016 Type of library Type of closed library  Closed New building  \
# 0            Yes             LAL                    NaN     NaN          NaN
# 1             No             NaN                     XL  Mar-13          NaN
# 2            Yes             LAL                    NaN     NaN       Oct-10
# 3             No             NaN                    XLR  Sep-10          NaN
# 4            Yes             CRL                    NaN     NaN          NaN
# ...          ...             ...                    ...     ...          ...
# 3272         Yes              CL                    NaN     NaN         2013
# 3273         yes              CL                    NaN     NaN          NaN
# 3274         yes              CL                    NaN     NaN          NaN
# 3275         yes              CL                    NaN     NaN          NaN
# 3276         yes              CL                    NaN     NaN          NaN
#
#      Replace existing  Weekly hours open  Weekly hours staffed
# 0                 NaN               72.0                  72.0
# 1                 NaN                NaN                   NaN
# 2                 Yes               56.0                  56.0
# 3                 NaN                NaN                   NaN
# 4                 NaN                9.0                   9.0
# ...               ...                ...                   ...
# 3272               No               45.5                  45.5
# 3273              NaN               19.0                  19.0
# 3274              NaN                NaN                   NaN
# 3275              NaN               41.0                  41.0
# 3276              NaN               65.0                  65.0
#
# [3277 rows x 11 columns]

# %%
def open_2016(data,name):
    df = data.reset_index()
    return df == name

# %%
open_2016(df, 'Barking')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
#       Library name  Library service  In use 2010  In use 2016  \
# 0             True            False        False        False
# 1            False            False        False        False
# 2            False            False        False        False
# 3            False            False        False        False
# 4            False            False        False        False
# ...            ...              ...          ...          ...
# 3272         False            False        False        False
# 3273         False            False        False        False
# 3274         False            False        False        False
# 3275         False            False        False        False
# 3276         False            False        False        False
#
#       Type of library  Type of closed library  Closed  New building  \
# 0               False                   False   False         False
# 1               False                   False   False         False
# 2               False                   False   False         False
# 3               False                   False   False         False
# 4               False                   False   False         False
# ...               ...                     ...     ...           ...
# 3272            False                   False   False         False
# 3273            False                   False   False         False
# 3274            False                   False   False         False
# 3275            False                   False   False         False
# 3276            False                   False   False         False
#
#       Replace existing  Weekly hours open  Weekly hours staffed
# 0                False              False                 False
# 1                False              False                 False
# 2                False              False                 False
# 3                False              False                 False
# 4                False              False                 False
# ...                ...                ...                   ...
# 3272             False              False                 False
# 3273             False              False                 False
# 3274             False              False                 False
# 3275             False              False                 False
# 3276             False              False                 False
#
# [3277 rows x 11 columns]

# %% [markdown]
# **Use the `.value_counts()` method on `df['In use 2010']` to see what different values there are in that column:**

# %%
df['In use 2010'].value_counts()
# Out:
# yes    2807
# Yes     256
# no      163
# No       49
# Name: In use 2010, dtype: int64

# %% [markdown]
# **Create a function called `is_open()`, which take a single value and returns a boolean value as follows:**
# - `True` if the value equals `'yes'` or `'Yes'`
# - `False` for any other value

# %%
def is_open(para1):
    return para1 == 'yes' or para1 =='Yes'

# %%
is_open('No'), is_open('yes')
# Out:
# (False, True)

# %% [markdown]
# **Use the `.apply()` method with your `is_open()` function and each of the columns `In use 2010` and `In use 2016`, to create new columns called `open_2010` and `open_2016` respectively, each containing Boolean values returned by the function:**

# %%
# unsure
df['open_2010'] =  df['In use 2010'].apply(is_open)
df['open_2016'] =  df['In use 2016'].apply(is_open)

# %%
df[['open_2010', 'open_2016']].dtypes
# Out:
# open_2010    bool
# open_2016    bool
# dtype: object

# %%
df['open_2010'].value_counts(), df['open_2016'].value_counts()
# Out:
# (True     3063
#  False     214
#  Name: open_2010, dtype: int64,
#  True     2763
#  False     514
#  Name: open_2016, dtype: int64)

# %% [markdown]
# **Create a new column in `df` called `open_both`, which contains a Boolean `True` for entries where both `open_2010` and `open_2016` are `True`:**

# %%
df['open_both'] = df['open_2010'] & df['open_2016']

# %%
df['open_both'].value_counts()
# Out:
# True     2637
# False     640
# Name: open_both, dtype: int64

# %% [markdown]
# **Assign to `df_open` a DataFrame containing only entries where `open_both == True`:**
# - use the `.copy()` method so that `df_open` can be subsequently modified without affecting `df`

# %%
df_open = df[df['open_both']==True].copy()
df_open
# Out:
#                                      Library service In use 2010 In use 2016  \
# Library name
# Barking                         Barking and Dagenham         Yes         Yes
# Marks Gate                      Barking and Dagenham         Yes         Yes
# Robert Jeyes Community Library  Barking and Dagenham         Yes         Yes
# Thames View                     Barking and Dagenham         Yes         Yes
# Valence                         Barking and Dagenham         Yes         Yes
# ...                                              ...         ...         ...
# New Earswick                                    York         yes         yes
# Poppleton                                       York         yes         yes
# Strensall                                       York         yes         yes
# Tang Hall                                       York         yes         yes
# York                                            York         yes         yes
#
#                                Type of library Type of closed library Closed  \
# Library name
# Barking                                    LAL                    NaN    NaN
# Marks Gate                                 CRL                    NaN    NaN
# Robert Jeyes Community Library             CRL                    NaN    NaN
# Thames View                                LAL                    NaN    NaN
# Valence                                    LAL                    NaN    NaN
# ...                                        ...                    ...    ...
# New Earswick                                CL                    NaN    NaN
# Poppleton                                   CL                    NaN    NaN
# Strensall                                   CL                    NaN    NaN
# Tang Hall                                   CL                    NaN    NaN
# York                                        CL                    NaN    NaN
#
#                                New building Replace existing  \
# Library name
# Barking                                 NaN              NaN
# Marks Gate                              NaN              NaN
# Robert Jeyes Community Library          NaN              NaN
# Thames View                             NaN              NaN
# Valence                                 NaN              NaN
# ...                                     ...              ...
# New Earswick                            NaN              NaN
# Poppleton                               NaN              NaN
# Strensall                               NaN              NaN
# Tang Hall                               NaN              NaN
# York                                    NaN              NaN
#
#                                 Weekly hours open  Weekly hours staffed  \
# Library name
# Barking                                      72.0                  72.0
# Marks Gate                                    9.0                   9.0
# Robert Jeyes Community Library               14.5                  14.5
# Thames View                                  30.0                  30.0
# Valence                                      36.0                  36.0
# ...                                           ...                   ...
# New Earswick                                 35.0                  35.0
# Poppleton                                    21.0                  21.0
# Strensall                                    19.0                  19.0
# Tang Hall                                    41.0                  41.0
# York                                         65.0                  65.0
#
#                                 open_2010  open_2016  open_both
# Library name
# Barking                              True       True       True
# Marks Gate                           True       True       True
# Robert Jeyes Community Library       True       True       True
# Thames View                          True       True       True
# Valence                              True       True       True
# ...                                   ...        ...        ...
# New Earswick                         True       True       True
# Poppleton                            True       True       True
# Strensall                            True       True       True
# Tang Hall                            True       True       True
# York                                 True       True       True
#
# [2637 rows x 13 columns]

# %%
len(df_open) == df['open_both'].value_counts()[True]
# Out:
# True

# %% [markdown]
# **Calculate the `.mean()` of the values in the `Weekly hours open` column:**

# %%
df['Weekly hours open'].mean()
# Out:
# 35.73440671908506

# %% [markdown]
# **Calculate the percentage of entries in `df_open` where `['Weekly hours open'] == 0`:**

# %%
len(df_open[df_open['Weekly hours open'] == 0]) / len(df_open) * 100
# Out:
# 2.123625331816458

# %% [markdown]
# Converting the zero values to `NaN` values will result those values being excluded from subsequent calculations of, for example, `.mean()`.
#
# These `NaN` values ('Not a Number') represent 'missing data' (of all types, not just numeric) in pandas.
#
# However (like many component of the data structures used by pandas) they originate from the `numpy` package, and thus to create them we need to `import numpy`, by convention `as np`:

# %%
import numpy as np

# %% [markdown]
# **`.apply()` a `lambda` function to modify `Weekly hours open` so that `if` the value `== 0` it is updated to `np.nan`, `else` it is unchanged:**

# %%
df_open['Weekly hours open'].apply(lambda x: np.nan if x == 0 else x )
# Out:
# Library name
# Barking                           72.0
# Marks Gate                         9.0
# Robert Jeyes Community Library    14.5
# Thames View                       30.0
# Valence                           36.0
#                                   ...
# New Earswick                      35.0
# Poppleton                         21.0
# Strensall                         19.0
# Tang Hall                         41.0
# York                              65.0
# Name: Weekly hours open, Length: 2637, dtype: float64

# %%
df_open['Weekly hours open'].value_counts()
# Out:
# 31.00     62
# 40.00     61
# 20.00     60
# 0.00      56
# 15.00     53
#           ..
# 26.75      1
# 69.00      1
# 214.00     1
# 120.50     1
# 148.75     1
# Name: Weekly hours open, Length: 193, dtype: int64

# %% [markdown]
# Run your earlier code to calculate the `.mean()` of `Weekly hours open` to see if the value is now different.

# %%
hours_in_week = 24 * 7

# %% [markdown]
# **Assign to df_errors a DataFrame containing entries from `df_open` where the value for `Weekly hours open` exceeds `hours_in_week`:**
# - use the `.copy()` method when creating the new DataFrame

# %%
df_open
# Out:
#                                      Library service In use 2010 In use 2016  \
# Library name
# Barking                         Barking and Dagenham         Yes         Yes
# Marks Gate                      Barking and Dagenham         Yes         Yes
# Robert Jeyes Community Library  Barking and Dagenham         Yes         Yes
# Thames View                     Barking and Dagenham         Yes         Yes
# Valence                         Barking and Dagenham         Yes         Yes
# ...                                              ...         ...         ...
# New Earswick                                    York         yes         yes
# Poppleton                                       York         yes         yes
# Strensall                                       York         yes         yes
# Tang Hall                                       York         yes         yes
# York                                            York         yes         yes
#
#                                Type of library Type of closed library Closed  \
# Library name
# Barking                                    LAL                    NaN    NaN
# Marks Gate                                 CRL                    NaN    NaN
# Robert Jeyes Community Library             CRL                    NaN    NaN
# Thames View                                LAL                    NaN    NaN
# Valence                                    LAL                    NaN    NaN
# ...                                        ...                    ...    ...
# New Earswick                                CL                    NaN    NaN
# Poppleton                                   CL                    NaN    NaN
# Strensall                                   CL                    NaN    NaN
# Tang Hall                                   CL                    NaN    NaN
# York                                        CL                    NaN    NaN
#
#                                New building Replace existing  \
# Library name
# Barking                                 NaN              NaN
# Marks Gate                              NaN              NaN
# Robert Jeyes Community Library          NaN              NaN
# Thames View                             NaN              NaN
# Valence                                 NaN              NaN
# ...                                     ...              ...
# New Earswick                            NaN              NaN
# Poppleton                               NaN              NaN
# Strensall                               NaN              NaN
# Tang Hall                               NaN              NaN
# York                                    NaN              NaN
#
#                                 Weekly hours open  Weekly hours staffed  \
# Library name
# Barking                                      72.0                  72.0
# Marks Gate                                    9.0                   9.0
# Robert Jeyes Community Library               14.5                  14.5
# Thames View                                  30.0                  30.0
# Valence                                      36.0                  36.0
# ...                                           ...                   ...
# New Earswick                                 35.0                  35.0
# Poppleton                                    21.0                  21.0
# Strensall                                    19.0                  19.0
# Tang Hall                                    41.0                  41.0
# York                                         65.0                  65.0
#
#                                 open_2010  open_2016  open_both
# Library name
# Barking                              True       True       True
# Marks Gate                           True       True       True
# Robert Jeyes Community Library       True       True       True
# Thames View                          True       True       True
# Valence                              True       True       True
# ...                                   ...        ...        ...
# New Earswick                         True       True       True
# Poppleton                            True       True       True
# Strensall                            True       True       True
# Tang Hall                            True       True       True
# York                                 True       True       True
#
# [2637 rows x 13 columns]

# %%
con3 = df_open['Weekly hours open']>hours_in_week
df_errors = df_open[con3].copy()

# %%
df_errors
# Out:
#                                                              Library service  \
# Library name
# Boscombe Library                                                 Bournemouth
# Bournemouth Library                                              Bournemouth
# Castlepoint Library                                              Bournemouth
# Kinson Hub                                                       Bournemouth
# Barrow Library                                                       Cumbria
# Beverley                                            East Riding of Yorkshire
# Bridlington                                         East Riding of Yorkshire
# Bridlington North                                   East Riding of Yorkshire
# Brough Library and Customer Service Centre          East Riding of Yorkshire
# Driffield Library & Customer Service Centre         East Riding of Yorkshire
# Goole                                               East Riding of Yorkshire
# Hessle Library and Customer Service Centre          East Riding of Yorkshire
# Market Weighton Library and Customer Service Ce...  East Riding of Yorkshire
# Pocklington                                         East Riding of Yorkshire
# Harrogate library                                            North Yorkshire
# Knaresborough library                                        North Yorkshire
# Malton library                                               North Yorkshire
# Northallerton library                                        North Yorkshire
# Ripon library                                                North Yorkshire
# Scarborough library                                          North Yorkshire
# Selby library                                                North Yorkshire
# Skipton library                                              North Yorkshire
# Newbury                                                       West Berkshire
#
#                                                    In use 2010 In use 2016  \
# Library name
# Boscombe Library                                           yes         yes
# Bournemouth Library                                        yes         yes
# Castlepoint Library                                        yes         yes
# Kinson Hub                                                 yes         yes
# Barrow Library                                             yes         yes
# Beverley                                                   yes         yes
# Bridlington                                                yes         yes
# Bridlington North                                          yes         yes
# Brough Library and Customer Service Centre                 yes         yes
# Driffield Library & Customer Service Centre                yes         yes
# Goole                                                      yes         yes
# Hessle Library and Customer Service Centre                 yes         yes
# Market Weighton Library and Customer Service Ce...         yes         yes
# Pocklington                                                yes         yes
# Harrogate library                                          yes         yes
# Knaresborough library                                      yes         yes
# Malton library                                             yes         yes
# Northallerton library                                      yes         yes
# Ripon library                                              yes         yes
# Scarborough library                                        yes         yes
# Selby library                                              yes         yes
# Skipton library                                            yes         yes
# Newbury                                                    yes         yes
#
#                                                    Type of library  \
# Library name
# Boscombe Library                                               LAL
# Bournemouth Library                                            LAL
# Castlepoint Library                                            LAL
# Kinson Hub                                                     LAL
# Barrow Library                                                 LAL
# Beverley                                                       LAL
# Bridlington                                                    LAL
# Bridlington North                                              LAL
# Brough Library and Customer Service Centre                     LAL
# Driffield Library & Customer Service Centre                    LAL
# Goole                                                          LAL
# Hessle Library and Customer Service Centre                     LAL
# Market Weighton Library and Customer Service Ce...             LAL
# Pocklington                                                    LAL
# Harrogate library                                              LAL
# Knaresborough library                                          LAL
# Malton library                                                 LAL
# Northallerton library                                          LAL
# Ripon library                                                  LAL
# Scarborough library                                            LAL
# Selby library                                                  LAL
# Skipton library                                                LAL
# Newbury                                                        LAL
#
#                                                    Type of closed library  \
# Library name
# Boscombe Library                                                      NaN
# Bournemouth Library                                                   NaN
# Castlepoint Library                                                   NaN
# Kinson Hub                                                            NaN
# Barrow Library                                                        NaN
# Beverley                                                              NaN
# Bridlington                                                           NaN
# Bridlington North                                                     NaN
# Brough Library and Customer Service Centre                            NaN
# Driffield Library & Customer Service Centre                           NaN
# Goole                                                                 NaN
# Hessle Library and Customer Service Centre                            NaN
# Market Weighton Library and Customer Service Ce...                    NaN
# Pocklington                                                           NaN
# Harrogate library                                                     NaN
# Knaresborough library                                                 NaN
# Malton library                                                        NaN
# Northallerton library                                                 NaN
# Ripon library                                                         NaN
# Scarborough library                                                   NaN
# Selby library                                                         NaN
# Skipton library                                                       NaN
# Newbury                                                               NaN
#
#                                                    Closed New building  \
# Library name
# Boscombe Library                                      NaN          NaN
# Bournemouth Library                                   NaN          NaN
# Castlepoint Library                                   NaN          NaN
# Kinson Hub                                            NaN          NaN
# Barrow Library                                        NaN          NaN
# Beverley                                              NaN          NaN
# Bridlington                                           NaN          NaN
# Bridlington North                                     NaN          NaN
# Brough Library and Customer Service Centre            NaN          NaN
# Driffield Library & Customer Service Centre           NaN          NaN
# Goole                                                 NaN          NaN
# Hessle Library and Customer Service Centre            NaN          NaN
# Market Weighton Library and Customer Service Ce...    NaN          NaN
# Pocklington                                           NaN          NaN
# Harrogate library                                     NaN          NaN
# Knaresborough library                                 NaN          NaN
# Malton library                                        NaN          NaN
# Northallerton library                                 NaN          NaN
# Ripon library                                         NaN          NaN
# Scarborough library                                   NaN          NaN
# Selby library                                         NaN          NaN
# Skipton library                                       NaN          NaN
# Newbury                                               NaN          NaN
#
#                                                    Replace existing  \
# Library name
# Boscombe Library                                                NaN
# Bournemouth Library                                             NaN
# Castlepoint Library                                             NaN
# Kinson Hub                                                      NaN
# Barrow Library                                                  NaN
# Beverley                                                        NaN
# Bridlington                                                     NaN
# Bridlington North                                               NaN
# Brough Library and Customer Service Centre                      NaN
# Driffield Library & Customer Service Centre                     NaN
# Goole                                                           NaN
# Hessle Library and Customer Service Centre                      NaN
# Market Weighton Library and Customer Service Ce...              NaN
# Pocklington                                                     NaN
# Harrogate library                                               NaN
# Knaresborough library                                           NaN
# Malton library                                                  NaN
# Northallerton library                                           NaN
# Ripon library                                                   NaN
# Scarborough library                                             NaN
# Selby library                                                   NaN
# Skipton library                                                 NaN
# Newbury                                                         NaN
#
#                                                     Weekly hours open  \
# Library name
# Boscombe Library                                               187.75
# Bournemouth Library                                            425.50
# Castlepoint Library                                            214.00
# Kinson Hub                                                     200.00
# Barrow Library                                                 429.00
# Beverley                                                       398.50
# Bridlington                                                    378.00
# Bridlington North                                              236.50
# Brough Library and Customer Service Centre                     206.50
# Driffield Library & Customer Service Centre                    205.00
# Goole                                                          327.67
# Hessle Library and Customer Service Centre                     192.50
# Market Weighton Library and Customer Service Ce...             204.00
# Pocklington                                                    218.50
# Harrogate library                                              462.00
# Knaresborough library                                          182.00
# Malton library                                                 200.00
# Northallerton library                                          238.00
# Ripon library                                                  187.00
# Scarborough library                                            362.00
# Selby library                                                  183.00
# Skipton library                                                238.00
# Newbury                                                        674.34
#
#                                                     Weekly hours staffed  \
# Library name
# Boscombe Library                                                  187.75
# Bournemouth Library                                               425.50
# Castlepoint Library                                               214.00
# Kinson Hub                                                        200.00
# Barrow Library                                                    429.00
# Beverley                                                          398.50
# Bridlington                                                       378.00
# Bridlington North                                                 236.50
# Brough Library and Customer Service Centre                        206.50
# Driffield Library & Customer Service Centre                       205.00
# Goole                                                             327.67
# Hessle Library and Customer Service Centre                        192.50
# Market Weighton Library and Customer Service Ce...                204.00
# Pocklington                                                       218.50
# Harrogate library                                                 462.00
# Knaresborough library                                             182.00
# Malton library                                                    200.00
# Northallerton library                                             238.00
# Ripon library                                                     187.00
# Scarborough library                                               362.00
# Selby library                                                     183.00
# Skipton library                                                   238.00
# Newbury                                                           674.34
#
#                                                     open_2010  open_2016  \
# Library name
# Boscombe Library                                         True       True
# Bournemouth Library                                      True       True
# Castlepoint Library                                      True       True
# Kinson Hub                                               True       True
# Barrow Library                                           True       True
# Beverley                                                 True       True
# Bridlington                                              True       True
# Bridlington North                                        True       True
# Brough Library and Customer Service Centre               True       True
# Driffield Library & Customer Service Centre              True       True
# Goole                                                    True       True
# Hessle Library and Customer Service Centre               True       True
# Market Weighton Library and Customer Service Ce...       True       True
# Pocklington                                              True       True
# Harrogate library                                        True       True
# Knaresborough library                                    True       True
# Malton library                                           True       True
# Northallerton library                                    True       True
# Ripon library                                            True       True
# Scarborough library                                      True       True
# Selby library                                            True       True
# Skipton library                                          True       True
# Newbury                                                  True       True
#
#                                                     open_both
# Library name
# Boscombe Library                                         True
# Bournemouth Library                                      True
# Castlepoint Library                                      True
# Kinson Hub                                               True
# Barrow Library                                           True
# Beverley                                                 True
# Bridlington                                              True
# Bridlington North                                        True
# Brough Library and Customer Service Centre               True
# Driffield Library & Customer Service Centre              True
# Goole                                                    True
# Hessle Library and Customer Service Centre               True
# Market Weighton Library and Customer Service Ce...       True
# Pocklington                                              True
# Harrogate library                                        True
# Knaresborough library                                    True
# Malton library                                           True
# Northallerton library                                    True
# Ripon library                                            True
# Scarborough library                                      True
# Selby library                                            True
# Skipton library                                          True
# Newbury                                                  True

# %% [markdown]
# **Use the `sort_values()` method on `df_errors` to look at the entries with the highest values for `Weekly hours open` at the top, i.e. in descending order:**

# %%
df_errors.sort_values('Weekly hours open',ascending = False)
# Out:
#                                                              Library service  \
# Library name
# Newbury                                                       West Berkshire
# Harrogate library                                            North Yorkshire
# Barrow Library                                                       Cumbria
# Bournemouth Library                                              Bournemouth
# Beverley                                            East Riding of Yorkshire
# Bridlington                                         East Riding of Yorkshire
# Scarborough library                                          North Yorkshire
# Goole                                               East Riding of Yorkshire
# Skipton library                                              North Yorkshire
# Northallerton library                                        North Yorkshire
# Bridlington North                                   East Riding of Yorkshire
# Pocklington                                         East Riding of Yorkshire
# Castlepoint Library                                              Bournemouth
# Brough Library and Customer Service Centre          East Riding of Yorkshire
# Driffield Library & Customer Service Centre         East Riding of Yorkshire
# Market Weighton Library and Customer Service Ce...  East Riding of Yorkshire
# Kinson Hub                                                       Bournemouth
# Malton library                                               North Yorkshire
# Hessle Library and Customer Service Centre          East Riding of Yorkshire
# Boscombe Library                                                 Bournemouth
# Ripon library                                                North Yorkshire
# Selby library                                                North Yorkshire
# Knaresborough library                                        North Yorkshire
#
#                                                    In use 2010 In use 2016  \
# Library name
# Newbury                                                    yes         yes
# Harrogate library                                          yes         yes
# Barrow Library                                             yes         yes
# Bournemouth Library                                        yes         yes
# Beverley                                                   yes         yes
# Bridlington                                                yes         yes
# Scarborough library                                        yes         yes
# Goole                                                      yes         yes
# Skipton library                                            yes         yes
# Northallerton library                                      yes         yes
# Bridlington North                                          yes         yes
# Pocklington                                                yes         yes
# Castlepoint Library                                        yes         yes
# Brough Library and Customer Service Centre                 yes         yes
# Driffield Library & Customer Service Centre                yes         yes
# Market Weighton Library and Customer Service Ce...         yes         yes
# Kinson Hub                                                 yes         yes
# Malton library                                             yes         yes
# Hessle Library and Customer Service Centre                 yes         yes
# Boscombe Library                                           yes         yes
# Ripon library                                              yes         yes
# Selby library                                              yes         yes
# Knaresborough library                                      yes         yes
#
#                                                    Type of library  \
# Library name
# Newbury                                                        LAL
# Harrogate library                                              LAL
# Barrow Library                                                 LAL
# Bournemouth Library                                            LAL
# Beverley                                                       LAL
# Bridlington                                                    LAL
# Scarborough library                                            LAL
# Goole                                                          LAL
# Skipton library                                                LAL
# Northallerton library                                          LAL
# Bridlington North                                              LAL
# Pocklington                                                    LAL
# Castlepoint Library                                            LAL
# Brough Library and Customer Service Centre                     LAL
# Driffield Library & Customer Service Centre                    LAL
# Market Weighton Library and Customer Service Ce...             LAL
# Kinson Hub                                                     LAL
# Malton library                                                 LAL
# Hessle Library and Customer Service Centre                     LAL
# Boscombe Library                                               LAL
# Ripon library                                                  LAL
# Selby library                                                  LAL
# Knaresborough library                                          LAL
#
#                                                    Type of closed library  \
# Library name
# Newbury                                                               NaN
# Harrogate library                                                     NaN
# Barrow Library                                                        NaN
# Bournemouth Library                                                   NaN
# Beverley                                                              NaN
# Bridlington                                                           NaN
# Scarborough library                                                   NaN
# Goole                                                                 NaN
# Skipton library                                                       NaN
# Northallerton library                                                 NaN
# Bridlington North                                                     NaN
# Pocklington                                                           NaN
# Castlepoint Library                                                   NaN
# Brough Library and Customer Service Centre                            NaN
# Driffield Library & Customer Service Centre                           NaN
# Market Weighton Library and Customer Service Ce...                    NaN
# Kinson Hub                                                            NaN
# Malton library                                                        NaN
# Hessle Library and Customer Service Centre                            NaN
# Boscombe Library                                                      NaN
# Ripon library                                                         NaN
# Selby library                                                         NaN
# Knaresborough library                                                 NaN
#
#                                                    Closed New building  \
# Library name
# Newbury                                               NaN          NaN
# Harrogate library                                     NaN          NaN
# Barrow Library                                        NaN          NaN
# Bournemouth Library                                   NaN          NaN
# Beverley                                              NaN          NaN
# Bridlington                                           NaN          NaN
# Scarborough library                                   NaN          NaN
# Goole                                                 NaN          NaN
# Skipton library                                       NaN          NaN
# Northallerton library                                 NaN          NaN
# Bridlington North                                     NaN          NaN
# Pocklington                                           NaN          NaN
# Castlepoint Library                                   NaN          NaN
# Brough Library and Customer Service Centre            NaN          NaN
# Driffield Library & Customer Service Centre           NaN          NaN
# Market Weighton Library and Customer Service Ce...    NaN          NaN
# Kinson Hub                                            NaN          NaN
# Malton library                                        NaN          NaN
# Hessle Library and Customer Service Centre            NaN          NaN
# Boscombe Library                                      NaN          NaN
# Ripon library                                         NaN          NaN
# Selby library                                         NaN          NaN
# Knaresborough library                                 NaN          NaN
#
#                                                    Replace existing  \
# Library name
# Newbury                                                         NaN
# Harrogate library                                               NaN
# Barrow Library                                                  NaN
# Bournemouth Library                                             NaN
# Beverley                                                        NaN
# Bridlington                                                     NaN
# Scarborough library                                             NaN
# Goole                                                           NaN
# Skipton library                                                 NaN
# Northallerton library                                           NaN
# Bridlington North                                               NaN
# Pocklington                                                     NaN
# Castlepoint Library                                             NaN
# Brough Library and Customer Service Centre                      NaN
# Driffield Library & Customer Service Centre                     NaN
# Market Weighton Library and Customer Service Ce...              NaN
# Kinson Hub                                                      NaN
# Malton library                                                  NaN
# Hessle Library and Customer Service Centre                      NaN
# Boscombe Library                                                NaN
# Ripon library                                                   NaN
# Selby library                                                   NaN
# Knaresborough library                                           NaN
#
#                                                     Weekly hours open  \
# Library name
# Newbury                                                        674.34
# Harrogate library                                              462.00
# Barrow Library                                                 429.00
# Bournemouth Library                                            425.50
# Beverley                                                       398.50
# Bridlington                                                    378.00
# Scarborough library                                            362.00
# Goole                                                          327.67
# Skipton library                                                238.00
# Northallerton library                                          238.00
# Bridlington North                                              236.50
# Pocklington                                                    218.50
# Castlepoint Library                                            214.00
# Brough Library and Customer Service Centre                     206.50
# Driffield Library & Customer Service Centre                    205.00
# Market Weighton Library and Customer Service Ce...             204.00
# Kinson Hub                                                     200.00
# Malton library                                                 200.00
# Hessle Library and Customer Service Centre                     192.50
# Boscombe Library                                               187.75
# Ripon library                                                  187.00
# Selby library                                                  183.00
# Knaresborough library                                          182.00
#
#                                                     Weekly hours staffed  \
# Library name
# Newbury                                                           674.34
# Harrogate library                                                 462.00
# Barrow Library                                                    429.00
# Bournemouth Library                                               425.50
# Beverley                                                          398.50
# Bridlington                                                       378.00
# Scarborough library                                               362.00
# Goole                                                             327.67
# Skipton library                                                   238.00
# Northallerton library                                             238.00
# Bridlington North                                                 236.50
# Pocklington                                                       218.50
# Castlepoint Library                                               214.00
# Brough Library and Customer Service Centre                        206.50
# Driffield Library & Customer Service Centre                       205.00
# Market Weighton Library and Customer Service Ce...                204.00
# Kinson Hub                                                        200.00
# Malton library                                                    200.00
# Hessle Library and Customer Service Centre                        192.50
# Boscombe Library                                                  187.75
# Ripon library                                                     187.00
# Selby library                                                     183.00
# Knaresborough library                                             182.00
#
#                                                     open_2010  open_2016  \
# Library name
# Newbury                                                  True       True
# Harrogate library                                        True       True
# Barrow Library                                           True       True
# Bournemouth Library                                      True       True
# Beverley                                                 True       True
# Bridlington                                              True       True
# Scarborough library                                      True       True
# Goole                                                    True       True
# Skipton library                                          True       True
# Northallerton library                                    True       True
# Bridlington North                                        True       True
# Pocklington                                              True       True
# Castlepoint Library                                      True       True
# Brough Library and Customer Service Centre               True       True
# Driffield Library & Customer Service Centre              True       True
# Market Weighton Library and Customer Service Ce...       True       True
# Kinson Hub                                               True       True
# Malton library                                           True       True
# Hessle Library and Customer Service Centre               True       True
# Boscombe Library                                         True       True
# Ripon library                                            True       True
# Selby library                                            True       True
# Knaresborough library                                    True       True
#
#                                                     open_both
# Library name
# Newbury                                                  True
# Harrogate library                                        True
# Barrow Library                                           True
# Bournemouth Library                                      True
# Beverley                                                 True
# Bridlington                                              True
# Scarborough library                                      True
# Goole                                                    True
# Skipton library                                          True
# Northallerton library                                    True
# Bridlington North                                        True
# Pocklington                                              True
# Castlepoint Library                                      True
# Brough Library and Customer Service Centre               True
# Driffield Library & Customer Service Centre              True
# Market Weighton Library and Customer Service Ce...       True
# Kinson Hub                                               True
# Malton library                                           True
# Hessle Library and Customer Service Centre               True
# Boscombe Library                                         True
# Ripon library                                            True
# Selby library                                            True
# Knaresborough library                                    True

# %% [markdown]
# **Use the `.unique()` series method and the `.tolist()` method to create a list of the unique values for `Library service` in `df_errors`:**

# %%
df_errors['Library service'].unique().tolist()
# Out:
# ['Bournemouth',
#  'Cumbria',
#  'East Riding of Yorkshire',
#  'North Yorkshire',
#  'West Berkshire']
